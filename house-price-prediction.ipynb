# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = {
    "area": [2600, 3000, 3200, 3600, 4000],
    "price": [550000, 565000, 610000, 680000, 725000]
}
df=pd.DataFrame(data)

# %%
df.tail()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='*')
plt.plot(df.area, reg.predict(df[['area']]), color='blue')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
print(reg.predict(pd.DataFrame([[3300]], columns=['area'])))
print(reg.predict(pd.DataFrame([[2000], [3500], [5000]], columns=['area'])))

print("Slope (coefficient):", reg.coef_)
print("Intercept:", reg.intercept_)
print("R² Score:", reg.score(df[['area']], df.price))
# Out:
# [628715.75342466]
# [452191.78082192 655873.28767123 859554.79452055]
# Slope (coefficient): [135.78767123]
# Intercept: 180616.43835616432
# R² Score: 0.9584301138199486

# %%
p = reg.predict(df[['area']])
print(p)
# Out:
# [533664.38356164 587979.45205479 615136.98630137 669452.05479452
#  723767.12328767]
